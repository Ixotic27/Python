# %% [markdown]
# write a python program by creating the class name calculator and two methods(add,sub) make sure these methods can handle n no. of variables
# Make the functions to add and sub for n variables

# %%
class Calculator:
    def add(self,*args):
        if not in args:
            return 0
        
        total=0
        for num in args:
            total+=num
        return total

    def sub():
        if not in args:
            return 0
        
        result = args[0]
        for num in args[1:]:
            total-=num
        return total    

# Create an instance of the Calculator
obj1 = Calculator()

# Create an empty list to store the numbers from the user
numbers = []

# Ask the user how many numbers they want to work with
try:
    n = int(input("How many numbers would you like to calculate with? "))

    # Get the numbers from the user
    for i in range(n):
        while True:
            try:
                # We use float() to allow for decimal numbers
                num = float(input(f"Enter number {i+1}: "))
                numbers.append(num)
                break # Exit the inner while loop if input is a valid number
            except ValueError:
                print("Invalid input. Please enter a valid number.")

    # Check if the list is not empty before performing calculations
    if numbers:
        # --- Perform Addition ---
        # The * operator unpacks the list, passing its elements as separate arguments
        # e.g., obj1.add(*[10, 5, 2]) is the same as obj1.add(10, 5, 2)
        sum = obj1.add(*numbers)
        print(f"\nThe sum of your numbers is: {sum}")

        # --- Perform Subtraction ---
        sub = obj1.sub(*numbers)
        print(f"The result of subtracting your numbers sequentially is: {sub}")
    else:
        print("\nNo numbers were entered to calculate.")

except ValueError:
    print("Invalid input. Please enter a whole number for the count.")
# Out:
#   Cell In[8], line 3
#     if not in args:
#            ^
# SyntaxError: invalid syntax
